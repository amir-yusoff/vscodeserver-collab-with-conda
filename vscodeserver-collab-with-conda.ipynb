# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-06-21 07:32:50--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  86.8MB/s    in 0.9s
#
# 2021-06-21 07:32:51 (86.8 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# # All requested packages already installed.
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
! pip install colabcode
# Out:
# Requirement already satisfied: colabcode in /usr/local/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: uvicorn==0.13.1 in /usr/local/lib/python3.7/site-packages (from colabcode) (0.13.1)
# Requirement already satisfied: jupyterlab==3.0.7 in /usr/local/lib/python3.7/site-packages (from colabcode) (3.0.7)
# Requirement already satisfied: nest-asyncio==1.4.3 in /usr/local/lib/python3.7/site-packages (from colabcode) (1.4.3)
# Requirement already satisfied: pyngrok>=5.0.0 in /usr/local/lib/python3.7/site-packages (from colabcode) (5.0.5)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.7/site-packages (from uvicorn==0.13.1->colabcode) (0.12.0)
# Requirement already satisfied: click==7.* in /usr/local/lib/python3.7/site-packages (from uvicorn==0.13.1->colabcode) (7.1.2)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from uvicorn==0.13.1->colabcode) (3.10.0.0)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (3.0.1)
# Requirement already satisfied: jupyterlab-server~=2.0 in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (2.6.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (7.24.1)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (6.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (4.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (20.9)
# Requirement already satisfied: jupyter-server~=1.2 in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (1.8.0)
# Requirement already satisfied: nbclassic~=0.2 in /usr/local/lib/python3.7/site-packages (from jupyterlab==3.0.7->colabcode) (0.3.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/site-packages (from pyngrok>=5.0.0->colabcode) (5.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from jinja2>=2.10->jupyterlab==3.0.7->colabcode) (2.0.1)
# Requirement already satisfied: json5 in /usr/local/lib/python3.7/site-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (0.9.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/site-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2.22.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/site-packages (from jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2.9.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (5.0.9)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (2.9.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (45.2.0.post20200210)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (5.0.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.18.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from ipython->jupyterlab==3.0.7->colabcode) (3.0.19)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/site-packages (from packaging->jupyterlab==3.0.7->colabcode) (2.4.7)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (20.1.0)
# Requirement already satisfied: jupyter-client>=6.1.1 in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (6.1.12)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.5.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.11.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (6.0.7)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (3.2.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (5.1.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.10.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (22.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/site-packages (from jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.2.0)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/site-packages (from nbclassic~=0.2->jupyterlab==3.0.7->colabcode) (6.4.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (1.14.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (0.17.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (4.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (21.2.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (3.0.4)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/site-packages (from babel->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->jupyterlab==3.0.7->colabcode) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyterlab==3.0.7->colabcode) (0.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.0.7->colabcode) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/site-packages (from argon2-cffi->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (2.8.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.5.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/site-packages (from nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab==3.0.7->colabcode) (5.5.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0.1->jupyterlab-server~=2.0->jupyterlab==3.0.7->colabcode) (3.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (2.19)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/site-packages (from bleach->nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (0.5.1)
# Requirement already satisfied: async-generator in /usr/local/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.2->jupyterlab==3.0.7->colabcode) (1.10)

# %%
from colabcode import ColabCode
ColabCode()
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://cb1f33cb98c7.ngrok.io" -> "http://localhost:10000"
# [2021-06-21T07:33:59.824Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-06-21T07:33:59.825Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-06-21T07:33:59.838Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-06-21T07:33:59.838Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-06-21T07:33:59.838Z] info    - Authentication is disabled
# [2021-06-21T07:33:59.838Z] info    - Not serving HTTPS
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
